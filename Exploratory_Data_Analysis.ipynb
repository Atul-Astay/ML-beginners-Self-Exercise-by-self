# %% [markdown]
# <a href="https://colab.research.google.com/github/Atul-Astay/ML-beginners-Self-Exercise-by-self/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Final Data.csv'
dataset = pd.read_csv(path,)

# %%
dataset
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 746    Gwen Stefani                           Crash      0
# 747    Gwen Stefani                       Luxurious      0
# 748         Rihanna    If It's Lovin' That You Want      0
# 749     Alicia Keys                     Unbreakable      0
# 750   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path  \
# 0    Songs/The Weeknd - Blinding Lights (Official V...
# 1    Songs/Olivia Rodrigo - good 4 u (Official Vide...
# 2    Songs/Olivia Rodrigo - drivers license (Offici...
# ...

# %%
dataset.isnull().sum()
# Out:
# Artist                           0
# Title                            0
# Label                            0
# Path                             0
# choruspath                       0
#                                 ..
# zero_crossing_rate_max_0         0
# zero_crossing_rate_std_0         0
# zero_crossing_rate_mean_0        0
# zero_crossing_rate_median_0      0
# zero_crossing_rate_kurtosis_0    0
# Length: 523, dtype: int64

# %%
dataset.dropna(axis = 0, inplace = True)

# %%
dataset.shape
# Out:
# (751, 523)

# %%
dataset.Label.value_counts()
# Out:
# 0    385
# 1    366
# Name: Label, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 751 entries, 0 to 750
# Columns: 523 entries, Artist to zero_crossing_rate_kurtosis_0
# dtypes: float64(518), int64(1), object(4)
# memory usage: 3.0+ MB

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.describe()
# Out:
#             Label  chroma_stft_kew_0  chroma_stft_min_0  chroma_stft_max_0  \
# count  751.000000         751.000000         751.000000         751.000000
# mean     0.487350           0.784881           0.017778           0.999902
# std      0.500173           0.566697           0.017097           0.002163
# min      0.000000          -0.716234           0.000111           0.943199
# 25%      0.000000           0.417220           0.006177           1.000000
# 50%      0.000000           0.768329           0.013053           1.000000
# 75%      1.000000           1.143469           0.023679           1.000000
# max      1.000000           3.263309           0.157747           1.000000
#
#        chroma_stft_std_0  chroma_stft_mean_0  chroma_stft_median_0  \
# count         751.000000          751.000000            751.000000
# mean            0.278146            0.398333              0.332541
# std             0.051261            0.116654              0.142720
# ...

# %%
dataset.Label.unique()
# Out:
# array([1, 0])

# %%
dataset.Artist.value_counts().head(10)
# Out:
# Taylor Swift        43
# Drake               34
# Justin Bieber       27
# Carrie Underwood    26
# The Weeknd          24
# Rihanna             24
# Chris Brown         21
# Rascal Flatts       20
# Juice WRLD          20
# Adele               20
# Name: Artist, dtype: int64

# %%
sns.histplot(x = 'Artist', y = 'Label', data = dataset,)

# %%
plt.figure(figsize = (16,14))
sns.barplot(x = 'Label', y = 'Artist', data = dataset,)

# %%
plt.figure(figsize = (14,10))
sns.heatmap(dataset.corr())

# %%
plt.figure(figsize = (20,8))
sns.boxplot(x = dataset['Artist'], y = dataset['Label'], data = dataset, )

# %%
len(dataset.Artist.unique())
# Out:
# 71

# %%
dataset['Artist'].value_counts().head(10)
# Out:
# Taylor Swift        43
# Drake               34
# Justin Bieber       27
# Carrie Underwood    26
# The Weeknd          24
# Rihanna             24
# Chris Brown         21
# Rascal Flatts       20
# Juice WRLD          20
# Adele               20
# Name: Artist, dtype: int64

# %%
popular_artist = ['Taylor Swift','Drake','Justin Bieber','Carrie Underwood','The Weeknd','Rihanna','Chris Brown','Rascal Flatts','Juice WRLD','Adele']
x = [43,34,27,26,24,24,21,20,20,20]
may_explode = [0.2,0,0,0,0,0,0,0,0,0]
fig = plt.figure(figsize = (10,8))
plt.pie(x,data = dataset, labels = popular_artist, shadow = True, explode = may_explode)
plt.legend(title = 'Top-Artist', loc = 'upper left')
plt.show()
